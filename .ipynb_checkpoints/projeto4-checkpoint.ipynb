# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2
import joblib
import os
import os.path
import re
from skimage.io import imread
from skimage.color import rgb2hsv
from skimage.measure import regionprops, perimeter

# %% [markdown]
# # Projeto: Pedra-Papel-Tesoura
#
# Neste projeto vocês devem construir um sistema que captura uma imagem da camera e diz se a imagem representa uma jogada de pedra, papel ou tesoura.
#
# Projeto em duplas.
#
# Entregável: Jupyter Notebook com a demonstração do sistema funcionando, e arquivo '.joblib' com o modelo treinado.
#
# Entrega: 9/10, 23:59
#
# Rubrica:
#
# - I - Não entregou ou entregou nonsense.
# - C - Funciona, mas com bugs menores.
# - A - Funciona bem.

# %% [markdown]
# ### Grupo:
# Iago Mendes e Jorge Augusto

# %% [markdown]
# Código para adquirir as imagens para treinar o modelo e as salva na pasta Data

# %%
import os.path

snap = 0

cap = cv2.VideoCapture(0)

_, frame = cap.read()
print(frame.shape)
while frame is not None:
    frame = frame[:, ::-1, :]
    
    frame_view = frame.copy()
    cv2.rectangle(frame_view, (220, 140), (420, 340), (0, 255, 0))
    cv2.imshow('frame', frame_view)
    

    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    elif k == ord('s'):
        filename = f'snap_{snap:05d}.png' 
        cv2.imwrite("Data/" + filename, frame)
        print(f'Saved {filename}')
        snap += 1

    _, frame = cap.read()

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Código que percorre os conteúdos d pasta Data, aplicando a devida morfologia para adequar as imagens ao modelo preditor. Esse código salva todas as novas imagens na pasta Train com o formato new-X.png, porém, esse tipo de nome só geraria uma única categoria quando introduzido como treinamento do modelo. Assim, os nomes das imagens da pasta Train foram alterados manualmente para se adequarem ao modelo de categorias.\
# A morfologia aplicada é um simples AND entre dois thresholds (um da Hue e outro da Saturation), que são feitos sobre as imagens das figuras de pedra, papel e tesoura desenhadas.

# %%
i = 0
for filename in os.listdir("Data"):
    img = rgb2hsv(imread("Data/" + filename))
    imgh = img[:,:,0] # é utilizada a componente "B" da imagem, pois as figuras desenhadas foram feitas em azul.
    imgh = (imgh > 0.5) & (imgh < 0.8)

    imgs = img[:,:,1]
    imgs = (imgs > 0.3)

    imga = imgh & imgs
    centro = imga[140:340,220:420]
    plt.imshow(centro, cmap="gray")
    plt.show()
    
    string = "Train/new-" + str(i) + ".png" 
    cv2.imwrite(string, (centro*255).astype('uint8'))
    
    i += 1

# %% [markdown]
# Leitura e listagem das imagens tratadas

# %%
def read_images():
    data_dir = os.path.join(os.getcwd(), 'Train')
    searcher = re.compile(r'^(.*)-(\d{0,2})\.png$') # Regex adequado
    imgs = {}
    for name in os.listdir(data_dir):
        match = searcher.search(name)
        cat = match.group(1)
        num = int(match.group(2))
        img = imread(os.path.join(data_dir, name))
        if not cat in imgs:
            imgs[cat] = []
        imgs[cat].append(img)
    return imgs

imgs_per_cat = read_images()

# %%
def show_images(imgs):
    C = 4
    N = len(imgs)
    R = (N - 1)//C + 1
    
    plt.figure(figsize=(C*3, R*3))
    for k, img in enumerate(imgs):
        plt.subplot(R, C, k+1)
        plt.imshow(img, cmap='gray')
    plt.show()

for cat, imgs in imgs_per_cat.items():
    print(f'{cat}: {len(imgs)} images')
    show_images(imgs)
# Out:
# papel: 8 images
# pedra: 8 images
# tesoura: 8 images

# %%
from skimage.measure import regionprops, perimeter

X = []
y = []

for cat, imgs in imgs_per_cat.items():
    for img in imgs:
        props = regionprops(img)[0]
        eccentricity = props['eccentricity']
        hu_moments = props['moments_hu']
        area = props['area']
        perimeter = props['perimeter']
        if perimeter == 0.0:
            perimeter = 1.0
        compactness = 4.0*np.pi*area/perimeter
        feats = [eccentricity, compactness] + list(hu_moments)
        X.append(feats)
        y.append(cat)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

clf = RandomForestClassifier(n_estimators=100)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# Devido ao pequeno número de imagens, sua simplicidade e sua qualidade estando muito padronizada, acabou por enviesar as predições de teste, gerando um acerto de 100%

# %%
print(y_test)
# Out:
# ['pedra', 'tesoura', 'papel', 'tesoura', 'pedra', 'pedra']

# %%
print(y_pred)
# Out:
# ['pedra' 'tesoura' 'papel' 'tesoura' 'pedra' 'pedra']

# %%
# Salvando o modelo
joblib.dump(clf, 'modelo_PPT.joblib')
# Out:
# ['modelo_PPT.joblib']

# %%
# Lendo o modelo.
clf = joblib.load('modelo_PPT.joblib')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

print(confusion_matrix(y_test, y_pred))
# Out:
# [[1 0 0]
#  [0 3 0]
#  [0 0 2]]

# %%
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(40, 40))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test, y_pred, classes=clf.classes_, normalize=True,
                      title='Confusion matrix, without normalization')

plt.show()
# Out:
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# Abaixo está o teste feito com imagens tiradas anteriormente, disponíveis na pasta Data. Essas não foram as imagens utilizadas para treinar o modelo, mas mesmo assim estão bem parecidas, enviesando os resultados.

# %%
img = rgb2hsv(imread("Data/snap_00018.png"))
imgh = img[:,:,0]
imgh = (imgh > 0.5) & (imgh < 0.8)

imgs = img[:,:,1]
imgs = (imgs > 0.3)

imga = imgh & imgs
centro = imga[140:340,220:420]
plt.imshow(centro, cmap="gray")
plt.show()

string = "Test/predict_.png" 
cv2.imwrite(string, (centro*255).astype('uint8'))
# Out:
# True

# %%
img = imread("Test/predict_.png", as_gray=True)

prediction = []

props = regionprops(img)[0]
eccentricity = props['eccentricity']
hu_moments = props['moments_hu']
area = props['area']
perimeter = props['perimeter']
if perimeter == 0.0:
    perimeter = 1.0
compactness = 4.0*np.pi*area/perimeter
feats = [eccentricity, compactness] + list(hu_moments)
prediction.append(feats)
# Out:
# c:\users\jorge\appdata\local\programs\python\python37-32\lib\site-packages\skimage\measure\_regionprops.py:250: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See https://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# c:\users\jorge\appdata\local\programs\python\python37-32\lib\site-packages\skimage\measure\_regionprops.py:260: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See https://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)

# %%
print(clf.predict(prediction))
# Out:
# ['pedra']

# %% [markdown]
# Agora, a versão do código que funciona juntamente com a câmera do computador e "joga" contra a imagem obtida, com base na predição desta

# %%
cap = cv2.VideoCapture(0)

_, frame = cap.read()
print(frame.shape)
while frame is not None:
    frame = frame[:, ::-1, :]
    
    frame_view = frame.copy()
    cv2.rectangle(frame_view, (220, 140), (420, 340), (0, 255, 0))
    cv2.imshow('frame', frame_view)
    

    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    elif k == ord(' '):  # Tecla de captura mudada para o espaço, para fins de praticidade
        filename = f'snap_predict.png'
        cv2.imwrite("Test/" + filename, frame)
        print(f'Saved {filename}')
        
        img = rgb2hsv(imread("Test/" + filename))
        imgh = img[:,:,0]
        imgh = (imgh > 0.5) & (imgh < 0.8)

        imgs = img[:,:,1]
        imgs = (imgs > 0.3)

        imga = imgh & imgs
        centro = imga[140:340,220:420]
        plt.imshow(centro, cmap="gray")
        plt.show()
        
        string = "Test/predict.png" 
        cv2.imwrite(string, (centro*255).astype('uint8'))
        
        
        img = imread("Test/predict.png", as_gray=True)

        image_prediction = []

        props = regionprops(img)[0]
        eccentricity = props['eccentricity']
        hu_moments = props['moments_hu']
        area = props['area']
        perimeter = props['perimeter']
        if perimeter == 0.0:
            perimeter = 1.0
        compactness = 4.0*np.pi*area/perimeter
        feats = [eccentricity, compactness] + list(hu_moments)
        image_prediction.append(feats)

        string = "Test/predict.png" 
        cv2.imwrite(string, (centro*255).astype('uint8'))
        print(clf.predict(image_prediction))
        
        

        if clf.predict(image_prediction) == "pedra":
            print("Para ganhar de você, eu escolho papel!")
        elif clf.predict(image_prediction) == "tesoura":
            print("Para ganhar de você, eu escolho pedra!")
        elif clf.predict(image_prediction) == "papel":
            print("Para ganhar de você, eu escolho tesoura!")

    _, frame = cap.read()

cap.release()
cv2.destroyAllWindows()
# Out:
# (480, 640, 3)
